# %%
import os
import json

# Obtém o diretório atual onde o notebook está localizado
diretorio = os.getcwd()

# Inicializa o total de registros
total_registros = 0

# Loop pelos arquivos no diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.json'):
        # Caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Lê o conteúdo do arquivo JSON
        with open(caminho_arquivo, 'r') as f:
            conteudo_json = json.load(f)
        
        # Conta o número de registros no arquivo JSON
        num_registros = len(conteudo_json)
        
        # Adiciona ao total de registros
        total_registros += num_registros
        
        print(f"Arquivo {arquivo} tem {num_registros} registros.")

# Exibe o total de registros
print("Número total de registros em todos os arquivos JSON:", total_registros)
# Out:
# Arquivo filmes_20.json tem 89 registros.
# Arquivo filmes_36.json tem 79 registros.
# Arquivo filmes_16.json tem 100 registros.
# Arquivo filmes_41.json tem 77 registros.
# Arquivo filmes_57.json tem 96 registros.
# Arquivo filmes_2.json tem 96 registros.
# Arquivo filmes_3.json tem 92 registros.
# Arquivo filmes_56.json tem 94 registros.
# Arquivo filmes_40.json tem 88 registros.
# Arquivo filmes_17.json tem 90 registros.
# Arquivo filmes_37.json tem 79 registros.
# Arquivo filmes_21.json tem 90 registros.
# Arquivo filmes_10.json tem 97 registros.
# Arquivo filmes_47.json tem 80 registros.
# Arquivo filmes_51.json tem 95 registros.
# Arquivo filmes_4.json tem 98 registros.
# Arquivo filmes_8.json tem 94 registros.
# Arquivo filmes_26.json tem 83 registros.
# Arquivo filmes_30.json tem 94 registros.
# Arquivo filmes_31.json tem 85 registros.
# Arquivo filmes_27.json tem 84 registros.
# Arquivo filmes_9.json tem 95 registros.
# Arquivo filmes_5.json tem 98 registros.
# Arquivo filmes_50.json tem 80 registros.
# Arquivo filmes_46.json tem 81 registros.
# Arquivo filmes_11.json tem 91 registros.
# Arquivo filmes_28.json tem 84 registros.
# Arquivo filmes_6.json tem 95 registros.
# Arquivo filmes_53.json tem 95 registros.
# Arquivo filmes_45.json tem 80 registros.
# Arquivo filmes_12.json tem 97 registros.
# Arquivo filmes_32.json tem 87 registros.
# Arquivo filmes_24.json tem 93 registros.
# Arquivo filmes_49.json tem 78 registros.
# Arquivo filmes_48.json tem 79 registros.
# Arquivo filmes_25.json tem 91 registros.
# Arquivo filmes_33.json tem 87 registros.
# Arquivo filmes_13.json tem 93 registros.
# Arquivo filmes_44.json tem 78 registros.
# Arquivo filmes_52.json tem 91 registros.
# Arquivo filmes_7.json tem 95 registros.
# Arquivo filmes_29.json tem 92 registros.
# Arquivo filmes_34.json tem 89 registros.
# Arquivo filmes_22.json tem 84 registros.
# Arquivo filmes_18.json tem 93 registros.
# Arquivo filmes_38.json tem 82 registros.
# Arquivo filmes_55.json tem 96 registros.
# Arquivo filmes_43.json tem 83 registros.
# Arquivo filmes_14.json tem 92 registros.
# Arquivo filmes_15.json tem 93 registros.
# Arquivo filmes_42.json tem 82 registros.
# Arquivo filmes_54.json tem 91 registros.
# Arquivo filmes_1.json tem 4418 registros.
# Arquivo filmes_39.json tem 78 registros.
# Arquivo filmes_19.json tem 97 registros.
# Arquivo filmes_58.json tem 78 registros.
# Arquivo filmes_23.json tem 93 registros.
# Arquivo filmes_35.json tem 92 registros.
# Número total de registros em todos os arquivos JSON: 9481

# %%
import os
import json
from collections import defaultdict

# Passo 1: Percorrer os arquivos JSON no diretório
directory = '.'  # Diretório atual
json_files = [file for file in os.listdir(directory) if file.endswith('.json')]

latin_american_films = []

# Passo 2 e 3: Ler e analisar o conteúdo de cada arquivo JSON e identificar os filmes da América do Sul
for file_name in json_files:
    with open(file_name, 'r', encoding='utf-8') as file:
        data = json.load(file)
        for movie in data:
            # Verifica se o filme é da América do Sul
            is_latin_american = False
            for country in movie.get('production_countries', []):
                if country['iso_3166_1'] in ['AR', 'BR', 'CL', 'CO', 'EC', 'GY', 'PE', 'SR', 'UY', 'VE']:
                    is_latin_american = True
                    break
            if is_latin_american:
                latin_american_films.append(movie)

# Passo 4: Classificar os filmes da América do Sul por popularidade (nota)
latin_american_films.sort(key=lambda x: x.get('vote_average', 0), reverse=True)

# Passo 5: Imprimir os top 100 filmes da América do Sul
print("\nTop 100 filmes da América do Sul:")
for i, movie in enumerate(latin_american_films[:100]):
    print(f"{i + 1}. {movie['title']} ({movie['vote_average']}) - {', '.join([country['name'] for country in movie['production_countries']])}")

# Passo 6: Contar quantos filmes de cada país da América do Sul estão no top 100
country_counts = defaultdict(int)
for movie in latin_american_films[:100]:
    for country in movie.get('production_countries', []):
        if country['iso_3166_1'] in ['AR', 'BR', 'CL', 'CO', 'EC', 'GY', 'PE', 'SR', 'UY', 'VE']:
            country_counts[country['name']] += 1

# Passo 7: Apresentar o número de filmes por país no top 100 da América do Sul
print("\nNúmero de filmes por país no top 100 da América do Sul:")
for country_name, count in country_counts.items():
    print(f"{country_name}: {count}")

# Passo 8: Imprimir o top 10 filmes de cada país da América do Sul
for country_name in country_counts.keys():
    country_movies = [movie for movie in latin_american_films if country_name in [c['name'] for c in movie['production_countries']]]
    country_movies.sort(key=lambda x: x.get('vote_average', 0), reverse=True)
    print(f"\nTop 10 filmes de {country_name}:")
    for i, movie in enumerate(country_movies[:10]):
        print(f"{i + 1}. {movie['title']} ({movie['vote_average']})")
# Out:
# Top 100 filmes da América do Sul:
# 1. Salamandra (10.0) - Belgium, Brazil, France, Germany, United Kingdom
# 2. Esencial (10.0) - Argentina
# 3. A Praia do Fim do Mundo (10.0) - Brazil
# 4. Doutor Gama (8.7) - Brazil
# 5. CATO (8.5) - Argentina
# 6. Rio Doce (8.5) - Brazil
# 7. Santa (8.3) - Argentina
# 8. Turma da Mônica: Lições (8.288) - Brazil
# 9. Los agitadores (8.1) - Argentina
# 10. Capitu e o Capítulo (8.0) - Brazil
# 11. Pixinguinha: Um Homem Carinhoso (8.0) - Brazil
# 12. La encomienda (8.0) - Argentina, Dominican Republic
# 13. Depois do Universo (7.974) - Brazil
# 14. Argentina, 1985 (7.928) - Argentina, United Kingdom
# 15. Ariel (7.75) - Argentina, Canada
# 16. A Noite do Fogo (7.7) - Argentina, Brazil, Germany, Qatar, Mexico, United States of America, Switzerland
# 17. Panash (7.5) - Argentina
# 18. Eu, Traidor (7.5) - Argentina
# 19. Nocturna - Lado B: Donde los elefantes van a morir (7.5) - Argentina
# 20. Marte Um (7.457) - Brazil
# 21. Pureza (7.441) - Brazil
# 22. Os Reis do Mundo (7.431) - Colombia, France, Luxembourg, Mexico, Norway
# 82. Granizo (6.344) - Argentina
# 83. Azor (6.336) - Argentina, France, Switzerland
# 84. A Ira de Deus (6.335) - Argentina
# 85. Os Primeiros Soldados (6.333) - Brazil
# 86. Paloma (6.333) - Brazil, Portugal
# 87. El castigo (6.3) - Argentina, Chile
# 88. Madalena (6.3) - Brazil
# 89. Un varón (6.3) - Colombia, France, Germany, Netherlands
# 90. Intervenção, É Proibido Morrer (6.3) - Brazil
# 91. Siete perros (6.3) - Argentina
# 92. O Menino Que Matou Meus Pais (6.278) - Brazil
# 93. Beckett (6.256) - Brazil, Italy
# 94. Noites de alface (6.25) - Brazil
# 95. Entre la niebla (6.25) - Colombia
# 96. Zahorí (6.2) - Argentina, Chile, France, Switzerland
# 97. Júpiter (6.2) - Brazil
# 98. Voces secretas (6.2) - Argentina
# 99. Amado (6.182) - Brazil
# 100. Como Matar a Besta (6.1) - Argentina, Brazil, Chile
#
# Número de filmes por país no top 100 da América do Sul:
# Brazil: 46
# Argentina: 43
# Colombia: 7
# Chile: 9
# Ecuador: 1
# Uruguay: 4
# Venezuela: 3
#
# Top 10 filmes de Brazil:
# 1. Salamandra (10.0)
# 2. A Praia do Fim do Mundo (10.0)
# 3. Doutor Gama (8.7)
# 4. Rio Doce (8.5)
# 5. Turma da Mônica: Lições (8.288)
# 6. Capitu e o Capítulo (8.0)
# 7. Pixinguinha: Um Homem Carinhoso (8.0)
# 8. Depois do Universo (7.974)
# 9. A Noite do Fogo (7.7)
# 10. Marte Um (7.457)
#
# Top 10 filmes de Argentina:
# 1. Esencial (10.0)
# 2. CATO (8.5)
# 3. Santa (8.3)
# 4. Los agitadores (8.1)
# 5. La encomienda (8.0)
# 6. Argentina, 1985 (7.928)
# 7. Ariel (7.75)
# 8. A Noite do Fogo (7.7)
# 9. Panash (7.5)
# 10. Eu, Traidor (7.5)
#
# Top 10 filmes de Colombia:
# 1. Os Reis do Mundo (7.431)
# 2. La ciudad de las fieras (7.3)
# 3. Llegaron de noche (6.7)
# 4. Leading Ladies (6.5)
# 5. La Jauría (6.4)
# 6. Un varón (6.3)
# 7. Entre la niebla (6.25)
# 8. Cavewoman (6.0)
# 9. Memória (5.984)
# 10. Amparo (5.4)
#
# Top 10 filmes de Chile:
# 1. Памфір (7.372)
# 2. 1976 (7.222)
# 3. Spencer (6.84)
# 4. The Year of the Everlasting Storm (6.563)
# 5. Un lugar llamado Dignidad (6.5)
# 6. Blanquita (6.5)
# 7. El castigo (6.3)
# 8. Zahorí (6.2)
# 9. Como Matar a Besta (6.1)
# 10. Coração Errante (6.1)
#
# Top 10 filmes de Ecuador:
# 1. La ciudad de las fieras (7.3)
# 2. Lo Invisible (5.7)
# 3. Al Oriente (4.3)
#
# Top 10 filmes de Uruguay:
# 1. Utama (7.2)
# 2. Noche americana (6.857)
# 3. A Uruguaia (6.8)
# 4. A Vida de Togo (6.469)
# 5. O Empregado e o Patrão (6.1)
# 6. El perfecto David (5.714)
# 7. El amigo visible (5.7)
# 8. Las Rojas (5.4)
# 9. 9 (5.0)
# 10. Las vacaciones de Hilda (4.5)
#
# Top 10 filmes de Venezuela:
# 1. Exorcismo Sagrado (7.113)
# 2. The Box (6.7)
# 3. Yo y las Bestias (6.6)
