# %%
import os
import json

# Obtém o diretório atual onde o notebook está localizado
diretorio = os.getcwd()

# Inicializa o total de registros
total_registros = 0

# Loop pelos arquivos no diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith('.json'):
        # Caminho completo para o arquivo
        caminho_arquivo = os.path.join(diretorio, arquivo)
        
        # Lê o conteúdo do arquivo JSON
        with open(caminho_arquivo, 'r') as f:
            conteudo_json = json.load(f)
        
        # Conta o número de registros no arquivo JSON
        num_registros = len(conteudo_json)
        
        # Adiciona ao total de registros
        total_registros += num_registros
        
        print(f"Arquivo {arquivo} tem {num_registros} registros.")

# Exibe o total de registros
print("Número total de registros em todos os arquivos JSON:", total_registros)
# Out:
# Arquivo filmes_156.json tem 82 registros.
# Arquivo filmes_290.json tem 92 registros.
# Arquivo filmes_101.json tem 91 registros.
# Arquivo filmes_228.json tem 89 registros.
# Arquivo filmes_117.json tem 91 registros.
# Arquivo filmes_140.json tem 93 registros.
# Arquivo filmes_286.json tem 85 registros.
# Arquivo filmes_269.json tem 89 registros.
# Arquivo filmes_77.json tem 83 registros.
# Arquivo filmes_212.json tem 87 registros.
# Arquivo filmes_183.json tem 88 registros.
# Arquivo filmes_20.json tem 85 registros.
# Arquivo filmes_245.json tem 93 registros.
# Arquivo filmes_300.json tem 88 registros.
# Arquivo filmes_195.json tem 90 registros.
# Arquivo filmes_36.json tem 83 registros.
# Arquivo filmes_253.json tem 90 registros.
# Arquivo filmes_316.json tem 22 registros.
# Arquivo filmes_61.json tem 96 registros.
# Arquivo filmes_204.json tem 92 registros.
# Arquivo filmes_273.json tem 85 registros.
# Arquivo filmes_16.json tem 91 registros.
# Arquivo filmes_224.json tem 91 registros.
# Arquivo filmes_41.json tem 88 registros.
# Arquivo filmes_232.json tem 82 registros.
# Arquivo filmes_57.json tem 90 registros.
# Arquivo filmes_265.json tem 89 registros.
# Arquivo filmes_2.json tem 1 registros.
# Arquivo filmes_137.json tem 91 registros.
# Arquivo filmes_249.json tem 91 registros.
# Arquivo filmes_160.json tem 92 registros.
# Arquivo filmes_199.json tem 85 registros.
# Arquivo filmes_176.json tem 87 registros.
# Arquivo filmes_208.json tem 90 registros.
# Arquivo filmes_82.json tem 78 registros.
# Arquivo filmes_121.json tem 92 registros.
# Arquivo filmes_83.json tem 86 registros.
# Arquivo filmes_120.json tem 97 registros.
# Arquivo filmes_209.json tem 91 registros.
# Arquivo filmes_198.json tem 89 registros.
# Arquivo filmes_177.json tem 89 registros.
# Arquivo filmes_161.json tem 90 registros.
# Arquivo filmes_248.json tem 90 registros.
# Arquivo filmes_136.json tem 91 registros.
# Arquivo filmes_3.json tem 84 registros.
# Arquivo filmes_264.json tem 90 registros.
# Arquivo filmes_56.json tem 86 registros.
# Arquivo filmes_233.json tem 92 registros.
# Arquivo filmes_40.json tem 87 registros.
# Arquivo filmes_225.json tem 93 registros.
# Arquivo filmes_17.json tem 85 registros.
# Arquivo filmes_272.json tem 79 registros.
# Arquivo filmes_205.json tem 91 registros.
# Arquivo filmes_60.json tem 89 registros.
# Arquivo filmes_252.json tem 89 registros.
# Arquivo filmes_194.json tem 89 registros.
# Arquivo filmes_37.json tem 90 registros.
# Arquivo filmes_244.json tem 91 registros.
# Arquivo filmes_301.json tem 88 registros.
# Arquivo filmes_182.json tem 88 registros.
# Arquivo filmes_21.json tem 86 registros.
# Arquivo filmes_213.json tem 89 registros.
# Arquivo filmes_76.json tem 81 registros.
# Arquivo filmes_287.json tem 92 registros.
# Arquivo filmes_268.json tem 90 registros.
# Arquivo filmes_141.json tem 90 registros.
# Arquivo filmes_116.json tem 91 registros.
# Arquivo filmes_229.json tem 90 registros.
# Arquivo filmes_100.json tem 83 registros.
# Arquivo filmes_291.json tem 91 registros.
# Arquivo filmes_157.json tem 97 registros.
# Arquivo filmes_275.json tem 92 registros.
# Arquivo filmes_10.json tem 90 registros.
# Arquivo filmes_222.json tem 89 registros.
# Arquivo filmes_47.json tem 89 registros.
# Arquivo filmes_234.json tem 89 registros.
# Arquivo filmes_51.json tem 90 registros.
# Arquivo filmes_263.json tem 88 registros.
# Arquivo filmes_4.json tem 88 registros.
# Arquivo filmes_218.json tem 92 registros.
# Arquivo filmes_131.json tem 88 registros.
# Arquivo filmes_189.json tem 95 registros.
# Arquivo filmes_166.json tem 86 registros.
# Arquivo filmes_259.json tem 90 registros.
# Arquivo filmes_170.json tem 92 registros.
# Arquivo filmes_84.json tem 86 registros.
# Arquivo filmes_127.json tem 90 registros.
# Arquivo filmes_150.json tem 87 registros.
# Arquivo filmes_296.json tem 90 registros.
# Arquivo filmes_279.json tem 87 registros.
# Arquivo filmes_107.json tem 87 registros.
# Arquivo filmes_111.json tem 89 registros.
# Arquivo filmes_238.json tem 82 registros.
# Arquivo filmes_146.json tem 90 registros.
# Arquivo filmes_8.json tem 91 registros.
# Arquivo filmes_280.json tem 88 registros.
# Arquivo filmes_71.json tem 89 registros.
# Arquivo filmes_214.json tem 91 registros.
# Arquivo filmes_185.json tem 87 registros.
# Arquivo filmes_26.json tem 89 registros.
# Arquivo filmes_243.json tem 91 registros.
# Arquivo filmes_306.json tem 89 registros.
# Arquivo filmes_193.json tem 90 registros.
# Arquivo filmes_30.json tem 85 registros.
# Arquivo filmes_255.json tem 91 registros.
# Arquivo filmes_310.json tem 88 registros.
# Arquivo filmes_67.json tem 84 registros.
# Arquivo filmes_202.json tem 87 registros.
# Arquivo filmes_203.json tem 82 registros.
# Arquivo filmes_66.json tem 85 registros.
# Arquivo filmes_254.json tem 88 registros.
# Arquivo filmes_311.json tem 86 registros.
# Arquivo filmes_192.json tem 84 registros.
# Arquivo filmes_31.json tem 82 registros.
# Arquivo filmes_242.json tem 88 registros.
# Arquivo filmes_307.json tem 93 registros.
# Arquivo filmes_184.json tem 92 registros.
# Arquivo filmes_27.json tem 91 registros.
# Arquivo filmes_215.json tem 92 registros.
# Arquivo filmes_70.json tem 80 registros.
# Arquivo filmes_281.json tem 88 registros.
# Arquivo filmes_147.json tem 88 registros.
# Arquivo filmes_239.json tem 86 registros.
# Arquivo filmes_110.json tem 92 registros.
# Arquivo filmes_106.json tem 91 registros.
# Arquivo filmes_297.json tem 88 registros.
# Arquivo filmes_278.json tem 89 registros.
# Arquivo filmes_151.json tem 85 registros.
# Arquivo filmes_126.json tem 88 registros.
# Arquivo filmes_171.json tem 84 registros.
# Arquivo filmes_258.json tem 90 registros.
# Arquivo filmes_188.json tem 87 registros.
# Arquivo filmes_167.json tem 90 registros.
# Arquivo filmes_130.json tem 87 registros.
# Arquivo filmes_219.json tem 92 registros.
# Arquivo filmes_5.json tem 91 registros.
# Arquivo filmes_262.json tem 93 registros.
# Arquivo filmes_50.json tem 93 registros.
# Arquivo filmes_235.json tem 94 registros.
# Arquivo filmes_46.json tem 85 registros.
# Arquivo filmes_223.json tem 91 registros.
# Arquivo filmes_11.json tem 96 registros.
# Arquivo filmes_274.json tem 88 registros.
# Arquivo filmes_69.json tem 90 registros.
# Arquivo filmes_125.json tem 82 registros.
# Arquivo filmes_172.json tem 90 registros.
# Arquivo filmes_28.json tem 91 registros.
# Arquivo filmes_164.json tem 92 registros.
# Arquivo filmes_308.json tem 82 registros.
# Arquivo filmes_133.json tem 89 registros.
# Arquivo filmes_6.json tem 91 registros.
# Arquivo filmes_148.json tem 94 registros.
# Arquivo filmes_261.json tem 85 registros.
# Arquivo filmes_53.json tem 83 registros.
# Arquivo filmes_236.json tem 90 registros.
# Arquivo filmes_109.json tem 90 registros.
# Arquivo filmes_45.json tem 85 registros.
# Arquivo filmes_220.json tem 94 registros.
# Arquivo filmes_12.json tem 91 registros.
# Arquivo filmes_277.json tem 84 registros.
# Arquivo filmes_298.json tem 92 registros.
# Arquivo filmes_200.json tem 90 registros.
# Arquivo filmes_129.json tem 90 registros.
# Arquivo filmes_65.json tem 80 registros.
# Arquivo filmes_312.json tem 85 registros.
# Arquivo filmes_257.json tem 91 registros.
# Arquivo filmes_32.json tem 88 registros.
# Arquivo filmes_191.json tem 84 registros.
# Arquivo filmes_304.json tem 92 registros.
# Arquivo filmes_241.json tem 91 registros.
# Arquivo filmes_168.json tem 86 registros.
# Arquivo filmes_24.json tem 86 registros.
# Arquivo filmes_187.json tem 89 registros.
# Arquivo filmes_216.json tem 90 registros.
# Arquivo filmes_73.json tem 91 registros.
# Arquivo filmes_282.json tem 86 registros.
# Arquivo filmes_144.json tem 89 registros.
# Arquivo filmes_113.json tem 94 registros.
# Arquivo filmes_49.json tem 83 registros.
# Arquivo filmes_105.json tem 93 registros.
# Arquivo filmes_294.json tem 87 registros.
# Arquivo filmes_152.json tem 88 registros.
# Arquivo filmes_153.json tem 92 registros.
# Arquivo filmes_295.json tem 85 registros.
# Arquivo filmes_48.json tem 84 registros.
# Arquivo filmes_104.json tem 90 registros.
# Arquivo filmes_112.json tem 90 registros.
# Arquivo filmes_145.json tem 91 registros.
# Arquivo filmes_283.json tem 94 registros.
# Arquivo filmes_72.json tem 85 registros.
# Arquivo filmes_217.json tem 89 registros.
# Arquivo filmes_169.json tem 88 registros.
# Arquivo filmes_25.json tem 87 registros.
# Arquivo filmes_186.json tem 89 registros.
# Arquivo filmes_305.json tem 89 registros.
# Arquivo filmes_240.json tem 88 registros.
# Arquivo filmes_33.json tem 90 registros.
# Arquivo filmes_190.json tem 86 registros.
# Arquivo filmes_313.json tem 89 registros.
# Arquivo filmes_256.json tem 90 registros.
# Arquivo filmes_128.json tem 92 registros.
# Arquivo filmes_64.json tem 82 registros.
# Arquivo filmes_201.json tem 95 registros.
# Arquivo filmes_276.json tem 91 registros.
# Arquivo filmes_299.json tem 93 registros.
# Arquivo filmes_13.json tem 90 registros.
# Arquivo filmes_221.json tem 89 registros.
# Arquivo filmes_108.json tem 93 registros.
# Arquivo filmes_44.json tem 86 registros.
# Arquivo filmes_237.json tem 85 registros.
# Arquivo filmes_52.json tem 87 registros.
# Arquivo filmes_260.json tem 83 registros.
# Arquivo filmes_7.json tem 91 registros.
# Arquivo filmes_149.json tem 87 registros.
# Arquivo filmes_132.json tem 89 registros.
# Arquivo filmes_309.json tem 90 registros.
# Arquivo filmes_29.json tem 90 registros.
# Arquivo filmes_165.json tem 93 registros.
# Arquivo filmes_173.json tem 89 registros.
# Arquivo filmes_68.json tem 92 registros.
# Arquivo filmes_124.json tem 94 registros.
# Arquivo filmes_206.json tem 88 registros.
# Arquivo filmes_63.json tem 87 registros.
# Arquivo filmes_314.json tem 90 registros.
# Arquivo filmes_251.json tem 86 registros.
# Arquivo filmes_178.json tem 82 registros.
# Arquivo filmes_34.json tem 93 registros.
# Arquivo filmes_197.json tem 84 registros.
# Arquivo filmes_302.json tem 95 registros.
# Arquivo filmes_247.json tem 88 registros.
# Arquivo filmes_22.json tem 83 registros.
# Arquivo filmes_181.json tem 86 registros.
# Arquivo filmes_210.json tem 89 registros.
# Arquivo filmes_139.json tem 89 registros.
# Arquivo filmes_75.json tem 78 registros.
# Arquivo filmes_284.json tem 95 registros.
# Arquivo filmes_142.json tem 92 registros.
# Arquivo filmes_59.json tem 84 registros.
# Arquivo filmes_115.json tem 90 registros.
# Arquivo filmes_103.json tem 93 registros.
# Arquivo filmes_292.json tem 90 registros.
# Arquivo filmes_18.json tem 91 registros.
# Arquivo filmes_154.json tem 91 registros.
# Arquivo filmes_123.json tem 92 registros.
# Arquivo filmes_80.json tem 85 registros.
# Arquivo filmes_38.json tem 89 registros.
# Arquivo filmes_174.json tem 91 registros.
# Arquivo filmes_162.json tem 83 registros.
# Arquivo filmes_79.json tem 87 registros.
# Arquivo filmes_135.json tem 93 registros.
# Arquivo filmes_267.json tem 80 registros.
# Arquivo filmes_288.json tem 93 registros.
# Arquivo filmes_119.json tem 84 registros.
# Arquivo filmes_55.json tem 96 registros.
# Arquivo filmes_230.json tem 85 registros.
# Arquivo filmes_43.json tem 92 registros.
# Arquivo filmes_226.json tem 84 registros.
# Arquivo filmes_158.json tem 89 registros.
# Arquivo filmes_14.json tem 93 registros.
# Arquivo filmes_271.json tem 87 registros.
# Arquivo filmes_270.json tem 91 registros.
# Arquivo filmes_159.json tem 91 registros.
# Arquivo filmes_15.json tem 90 registros.
# Arquivo filmes_227.json tem 89 registros.
# Arquivo filmes_42.json tem 86 registros.
# Arquivo filmes_231.json tem 88 registros.
# Arquivo filmes_118.json tem 96 registros.
# Arquivo filmes_54.json tem 87 registros.
# Arquivo filmes_266.json tem 82 registros.
# Arquivo filmes_289.json tem 91 registros.
# Arquivo filmes_1.json tem 90 registros.
# Arquivo filmes_78.json tem 79 registros.
# Arquivo filmes_134.json tem 89 registros.
# Arquivo filmes_163.json tem 87 registros.
# Arquivo filmes_39.json tem 81 registros.
# Arquivo filmes_175.json tem 89 registros.
# Arquivo filmes_122.json tem 88 registros.
# Arquivo filmes_81.json tem 92 registros.
# Arquivo filmes_19.json tem 87 registros.
# Arquivo filmes_155.json tem 88 registros.
# Arquivo filmes_293.json tem 91 registros.
# Arquivo filmes_102.json tem 91 registros.
# Arquivo filmes_58.json tem 84 registros.
# Arquivo filmes_114.json tem 90 registros.
# Arquivo filmes_143.json tem 92 registros.
# Arquivo filmes_285.json tem 85 registros.
# Arquivo filmes_138.json tem 87 registros.
# Arquivo filmes_74.json tem 89 registros.
# Arquivo filmes_211.json tem 91 registros.
# Arquivo filmes_23.json tem 86 registros.
# Arquivo filmes_180.json tem 95 registros.
# Arquivo filmes_303.json tem 85 registros.
# Arquivo filmes_246.json tem 82 registros.
# Arquivo filmes_179.json tem 83 registros.
# Arquivo filmes_35.json tem 92 registros.
# Arquivo filmes_196.json tem 90 registros.
# Arquivo filmes_315.json tem 95 registros.
# Arquivo filmes_250.json tem 90 registros.
# Arquivo filmes_62.json tem 79 registros.
# Arquivo filmes_207.json tem 86 registros.
# Número total de registros em todos os arquivos JSON: 26427

# %%
import os
import json
from collections import defaultdict

# Passo 1: Percorrer os arquivos JSON no diretório
directory = '.'  # Diretório atual
json_files = [file for file in os.listdir(directory) if file.endswith('.json')]

latin_american_films = []

# Passo 2 e 3: Ler e analisar o conteúdo de cada arquivo JSON e identificar os filmes da América do Sul
for file_name in json_files:
    with open(file_name, 'r', encoding='utf-8') as file:
        data = json.load(file)
        for movie in data:
            # Verifica se o filme é da América do Sul
            is_latin_american = False
            for country in movie.get('production_countries', []):
                if country['iso_3166_1'] in ['AR', 'BR', 'CL', 'CO', 'EC', 'GY', 'PE', 'SR', 'UY', 'VE']:
                    is_latin_american = True
                    break
            if is_latin_american:
                latin_american_films.append(movie)

# Passo 4: Classificar os filmes da América do Sul por popularidade (nota)
latin_american_films.sort(key=lambda x: x.get('vote_average', 0), reverse=True)

# Passo 5: Imprimir os top 100 filmes da América do Sul
print("\nTop 100 filmes da América do Sul:")
for i, movie in enumerate(latin_american_films[:100]):
    print(f"{i + 1}. {movie['title']} ({movie['vote_average']}) - {', '.join([country['name'] for country in movie['production_countries']])}")

# Passo 6: Contar quantos filmes de cada país da América do Sul estão no top 100
country_counts = defaultdict(int)
for movie in latin_american_films[:100]:
    for country in movie.get('production_countries', []):
        if country['iso_3166_1'] in ['AR', 'BR', 'CL', 'CO', 'EC', 'GY', 'PE', 'SR', 'UY', 'VE']:
            country_counts[country['name']] += 1

# Passo 7: Apresentar o número de filmes por país no top 100 da América do Sul
print("\nNúmero de filmes por país no top 100 da América do Sul:")
for country_name, count in country_counts.items():
    print(f"{country_name}: {count}")

# Passo 8: Imprimir o top 10 filmes de cada país da América do Sul
for country_name in country_counts.keys():
    country_movies = [movie for movie in latin_american_films if country_name in [c['name'] for c in movie['production_countries']]]
    country_movies.sort(key=lambda x: x.get('vote_average', 0), reverse=True)
    print(f"\nTop 10 filmes de {country_name}:")
    for i, movie in enumerate(country_movies[:10]):
        print(f"{i + 1}. {movie['title']} ({movie['vote_average']})")
# Out:
# Top 100 filmes da América do Sul:
# 1. Perros sin cola (10.0) - Chile
# 2. Tierra yerma (10.0) - United Kingdom, Chile, France
# 3. Salamandra (10.0) - Belgium, Brazil, France, Germany, United Kingdom
# 4. Extirpador de Idolatrias (10.0) - Peru
# 5. Vestigio (10.0) - Argentina
# 6. Esencial (10.0) - Argentina
# 7. Ana. Sem Título (10.0) - Brazil
# 8. Verlust (10.0) - Brazil, Uruguay
# 9. Um Filme Francês (10.0) - Brazil
# 10. Ojalá vivas tiempos interesantes (10.0) - Argentina
# 11. Tiempo Suspendido (10.0) - Argentina, Mexico
# 12. Metade do Céu (10.0) - South Africa, Brazil, China, India, Russia
# 13. Norte (10.0) - Peru
# 14. Boi de Lágrimas (10.0) - Brazil
# 15. Theo, além da liberdade (10.0) - Brazil
# 16. Histórias de Alice (10.0) - Brazil, Portugal
# 17. A Praia do Fim do Mundo (10.0) - Brazil
# 18. Las mujeres deciden (10.0) - Ecuador
# 19. Helen (9.5) - Brazil
# 20. Los del suelo (9.5) - Argentina
# 21. Pule ou Ocorrência às 4h48 (9.3) - Brazil
# 22. Sertânia (9.1) - Brazil
# 23. Daqui até a China (9.1) - Argentina
# 24. #eagoraoque (9.0) - Brazil
# 25. Sobre Rodas (9.0) - Brazil
# 26. Hojas verdes de otoño (9.0) - Argentina
# 27. Machado do Brasil (9.0) - Brazil
# 28. Román (9.0) - Argentina
# 29. Doutor Gama (8.7) - Brazil
# 30. O Mercado de Notícias (8.7) - Brazil
# 31. Um Dia com Jerusa (8.5) - Brazil
# 32. Angelita, la doctora (8.5) - Argentina
# 33. Yasuni Man (8.5) - Ecuador, Spain, United States of America
# 34. Ónix (8.5) - Argentina
# 35. Rio Doce (8.5) - Brazil
# 36. Edición ilimitada (8.5) - Argentina
# 37. CATO (8.5) - Argentina
# 38. NN (8.5) - Colombia, France, Germany, Peru
# 39. La última tarde (8.4) - Peru
# 40. Divaldo: O Mensageiro da Paz (8.37) - Brazil
# 41. Santa (8.3) - Argentina
# 42. Turma da Mônica: Lições (8.288) - Brazil
# 43. Loop (8.214) - Brazil
# 44. João, o Maestro (8.2) - Brazil
# 45. Agujero Negro (8.2) - Dominican Republic, Ecuador
# 46. Dolores - Uma Mulher, Dois Amores (8.2) - Argentina, Brazil
# 47. Manco Capac (8.2) - Peru
# 48. Me Chame Pelo Seu Nome (8.152) - Brazil, France, Italy, United States of America
# 49. Soldado Argentino solo conocido por Dios (8.106) - Argentina
# 50. Que Horas Ela Volta? (8.031) - Brazil
# 51. Mas que hermanos (8.017) - Panama, Argentina, United States of America
# 52. La encomienda (8.0) - Argentina, Dominican Republic
# 53. Pixinguinha: Um Homem Carinhoso (8.0) - Brazil
# 54. Filhos de Bach (8.0) - Brazil, Germany
# 55. Estive em Lisboa e Lembrei de Você (8.0) - Brazil, Portugal
# 56. Entre ríos: todo lo que no dijimos (8.0) - Argentina
# 57. Bingo: O Rei das Manhãs (8.0) - Brazil
# 58. King Kong em Asunción (8.0) - Bolivia, Brazil, Paraguay
# 59. La noche más fria (8.0) - Argentina
# 60. Tiempo perdido (8.0) - Argentina
# 61. Tragam-Me a Cabeça de Carmen M. (8.0) - Brazil, Portugal
# 62. Crisis (8.0) - Chile
# 63. Petecuy, La Película (8.0) - Colombia, Spain
# 64. La escuela del bosque (8.0) - Argentina, Spain
# 65. El Silencio del Río (8.0) - Colombia, France, Uruguay
# 66. A Fera na Selva (8.0) - Brazil
# 67. Muitos Homens Num Só (8.0) - Brazil
# 68. Depois do Universo (7.974) - Brazil
# 69. Argentina, 1985 (7.927) - Argentina, United Kingdom
# 70. A Son of Man (7.917) - Ecuador
# 71. Chaco (7.9) - Argentina, Bolivia
# 72. Arábia (7.9) - Brazil
# 73. Primos (7.9) - Brazil
# 74. O Loiro (7.9) - Argentina
# 75. Hoje Eu Quero Voltar Sozinho (7.9) - Brazil
# 76. A Vida Invisível (7.887) - Brazil, Germany
# 77. Pacarrete (7.882) - Brazil
# 78. Relatos Selvagens (7.868) - Argentina, Spain
# 79. La mujer del animal (7.847) - Colombia
# 80. O Baile dos 41 (7.831) - Brazil, Mexico
# 81. Café com Canela (7.828) - Brazil
# 82. A História da Eternidade (7.8) - Brazil
# 83. Yonlu (7.8) - Brazil
# 84. Eternidade (7.8) - Peru
# 85. Vicenta (7.8) - Argentina
# 86. Metanoia (7.8) - Brazil
# 87. Rumbo al mar (7.8) - Argentina
# 88. Palau: Um Homem de Fé (7.789) - Argentina
# 89. A Vizinhança do Tigre (7.778) - Brazil
# 90. Eduardo e Mônica (7.757) - Brazil
# 91. Ariel (7.75) - Argentina, Canada
# 92. A Noite do Fogo (7.7) - Argentina, Brazil, Germany, Qatar, Mexico, United States of America, Switzerland
# 93. A Passageira (7.7) - Argentina, Colombia, Peru
# 94. O Abraço da Serpente (7.679) - Argentina, Colombia, Venezuela
# 95. O Traidor (7.678) - Brazil, France, Germany, Italy
# 96. Entre Irmãs (7.675) - Brazil
# 97. Marighella (7.642) - Brazil
# 98. Yo, adolescente (7.629) - Argentina
# 99. O Patrão: Radiografia de um Crime (7.604) - Venezuela, Argentina
# 100. A Grande Dama do Cinema (7.6) - Argentina, Spain
#
# Número de filmes por país no top 100 da América do Sul:
# Chile: 3
# Brazil: 51
# Peru: 7
# Argentina: 35
# Uruguay: 2
# Ecuador: 4
# Colombia: 6
# Venezuela: 2
#
# Top 10 filmes de Chile:
# 1. Perros sin cola (10.0)
# 2. Tierra yerma (10.0)
# 3. Crisis (8.0)
# 4. Os Fortes (7.6)
# 5. La casa lobo (7.585)
# 6. Poesia Sem Fim (7.56)
# 7. Pacto de Fuga (7.5)
# 8. Памфір (7.344)
# 9. El bosque de Karadima (7.3)
# 10. Tenho Medo Toureiro (7.282)
#
# Top 10 filmes de Brazil:
# 1. Salamandra (10.0)
# 2. Ana. Sem Título (10.0)
# 3. Verlust (10.0)
# 4. Um Filme Francês (10.0)
# 5. Metade do Céu (10.0)
# 6. Boi de Lágrimas (10.0)
# 7. Theo, além da liberdade (10.0)
# 8. Histórias de Alice (10.0)
# 9. A Praia do Fim do Mundo (10.0)
# 10. Helen (9.5)
#
# Top 10 filmes de Peru:
# 1. Extirpador de Idolatrias (10.0)
# 2. Norte (10.0)
# 3. NN (8.5)
# 4. La última tarde (8.4)
# 5. Manco Capac (8.2)
# 6. Eternidade (7.8)
# 7. A Passageira (7.7)
# 8. Caixa de Recordações (7.4)
# 9. Atacada: la teoría del dolor (7.3)
# 10. The Last Shaman (7.224)
#
# Top 10 filmes de Argentina:
# 1. Vestigio (10.0)
# 2. Esencial (10.0)
# 3. Ojalá vivas tiempos interesantes (10.0)
# 4. Tiempo Suspendido (10.0)
# 5. Los del suelo (9.5)
# 6. Daqui até a China (9.1)
# 7. Hojas verdes de otoño (9.0)
# 8. Román (9.0)
# 9. Angelita, la doctora (8.5)
# 10. Ónix (8.5)
#
# Top 10 filmes de Uruguay:
# 1. Verlust (10.0)
# 2. El Silencio del Río (8.0)
# 3. Gilda: Não Me Arrependo Desse Amor (7.6)
# 4. Benzinho (7.6)
# 5. Utama (7.2)
# 6. 23 Segundos (7.0)
# 7. Tamara (7.0)
# 8. Planta permanente (6.9)
# 9. Vida de Doleiro (6.9)
# 10. Noche americana (6.857)
#
# Top 10 filmes de Ecuador:
# 1. Las mujeres deciden (10.0)
# 2. Yasuni Man (8.5)
# 3. Agujero Negro (8.2)
# 4. A Son of Man (7.917)
# 5. La ciudad de las fieras (7.3)
# 6. Azules Turquesas (7.0)
# 7. Translúcido (7.0)
# 8. Vírus Tropical (6.881)
# 9. Vacío (6.8)
# 10. Alba (6.75)
#
# Top 10 filmes de Colombia:
# 1. NN (8.5)
# 2. Petecuy, La Película (8.0)
# 3. El Silencio del Río (8.0)
# 4. La mujer del animal (7.847)
# 5. A Passageira (7.7)
# 6. O Abraço da Serpente (7.679)
# 7. A Ausência que Seremos (7.565)
# 8. Os Reis do Mundo (7.431)
# 9. Siempreviva (7.4)
# 10. Anna (7.4)
#
# Top 10 filmes de Venezuela:
# 1. O Abraço da Serpente (7.679)
# 2. O Patrão: Radiografia de um Crime (7.604)
# 3. El Inca (7.5)
# 4. La fortaleza (7.338)
# 5. Dos otoños en París (7.3)
# 6. Exorcismo Sagrado (7.113)
# 7. Tamara (7.0)
# 8. Lejos de casa - Película Venezolana (6.8)
# 9. Allende en su laberinto (6.7)
# 10. The Box (6.7)
